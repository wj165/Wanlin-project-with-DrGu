# %% [markdown]
# # GU003 Pipeline — From GeoJSON

# %%
from pipeline_from_geojson import run_pipeline

GEOJSON_DIR = 'your_geojson_dir_here'
OUTPUT_DIR = 'your_output_dir_here'

run_pipeline(GEOJSON_DIR, OUTPUT_DIR)
