# %% [markdown]
# # GU003 Pipeline — From Image

# %%
from pipeline_from_image import run_pipeline

PATCH_DIR = 'your_patch_dir_here'
OUTPUT_DIR = 'your_output_dir_here'

run_pipeline(PATCH_DIR, OUTPUT_DIR)
