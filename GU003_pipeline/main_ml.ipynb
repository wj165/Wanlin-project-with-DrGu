# %% [markdown]
# # GU003 ML Notebook (69 Features Only)\nAutoGluon Case-level Training

# %%
from ml_module import GU003AutoML\n\nDATA_PATH = 'YOUR_FINAL_PATCH_CSV_PATH'\nOUTPUT_DIR = 'YOUR_OUTPUT_DIRECTORY'\n\nml = GU003AutoML(DATA_PATH, OUTPUT_DIR)\nresults = ml.run()\nprint(results)
